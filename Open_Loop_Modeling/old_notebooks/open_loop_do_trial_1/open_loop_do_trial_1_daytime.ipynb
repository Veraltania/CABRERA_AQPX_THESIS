# %% [markdown]
# TRIAL 1: FEBRUARY 5, 2026, DAYTIME

# %%
from Open_Loop_Modeling.open_loop_modeling_tools import *

# %%
file_name = r'D:\aqpx\Cabrera_Thesis_AQPX\Open_Loop_Modeling\data\AQPX_data_log_2026-02-05.csv'
target_column = 'MCP_WQ_DO'

window_seconds=60
df1_day = extract_and_process(file_name, '2026-02-05 10:00:00', '2026-02-05 15:00:00',
                          target_column, window_seconds)
# Out:
# Moving average: 60s window = 13 samples at fs=0.20 Hz
# Effective lag: 30.0 seconds (centered window, so zero lag)

# %%
start_step = '2026-02-05 10:00:00'
end_step = '2026-02-05 15:00:00'

# List of models to test
models_to_test = ['FOPTD', 'SOPTD', 'TOPTD', 'FOPTDLD', 'SOPTDLD']

for model in models_to_test:
    print(f"--- Processing {model} ---")
    fit_any_model(df1_day, model, start_step, end_step)
# Out:
# --- Processing FOPTD ---
# --- Processing SOPTD ---
# --- Processing TOPTD ---
# --- Processing FOPTDLD ---
# --- Processing SOPTDLD ---
