# %% [markdown]
# TRIAL 3: FEBRUARY 7, 2026, NIGHTTIME

# %%
from Open_Loop_Modeling.open_loop_modeling_tools import *

# %%
file_name = r'C:\Users\Dindo\Documents\aqpx\Cabrera_Thesis_AQPX\Open_Loop_Modeling\data\AQPX_data_log_2026-02-07.csv'
target_column = 'MCP_WQ_DO'

df3_night = extract_and_process(file_name, '2026-02-07 20:00:00', '2026-02-07 23:59:59',
                          target_column, filter_minutes=10)
# Out:
# Processing range: 2026-02-07 20:00:00 - 2026-02-07 23:59:59
# Estimated Sampling Frequency: 0.2000 Hz
# Filter designed: Preserves variations SLOWER than 10 minutes.

# %%
start_step = '2026-02-07 20:00:00'
end_step = '2026-02-07 23:59:59'

# List of models to test
models_to_test = ['FOPTD', 'SOPTD', 'TOPTD', 'FOPTDLD', 'SOPTDLD']

for model in models_to_test:
    print(f"--- Processing {model} ---")
    fit_any_model(df3_night, model, start_step, end_step)
# Out:
# --- Processing FOPTD ---
# --- Processing SOPTD ---
# --- Processing TOPTD ---
# --- Processing FOPTDLD ---
# --- Processing SOPTDLD ---
