# %% [markdown]
# TRIAL 2: FEBRUARY 5, 2026

# %%
from Transfer_Function_Modeling.open_loop_modeling_tools import *

# %%
file_name = r'C:\Users\Dindo\Documents\aqpx\Cabrera_Thesis_AQPX\Open_Loop_Modeling\data\AQPX_data_log_2026-02-05.csv'
target_column = 'MCP_WQ_TDS'

df1_day = extract_and_process(file_name, '2026-02-05 17:00:00', '2026-02-05 21:00:00',
                          target_column, filter_minutes=10)
# Out:
# Processing range: 2026-02-05 17:00:00 - 2026-02-05 21:00:00
# Estimated Sampling Frequency: 0.2000 Hz
# Filter designed: Preserves variations SLOWER than 10 minutes.

# %%
start_step = '2026-02-06 03:00:00'
end_step = '2026-02-06 11:00:00'

# List of models to test
models_to_test = ['FOPTD', 'SOPTD', 'TOPTD', 'FOPTDLD', 'SOPTDLD']

for model in models_to_test:
    print(f"--- Processing {model} ---")
    fit_any_model(df1_day, model, start_step, end_step, raw_col='MCP_WQ_TDS', filtered_col="MCP_WQ_TDS_filtered")
# Out:
# --- Processing FOPTD ---
# --- Processing SOPTD ---
# --- Processing TOPTD ---
# --- Processing FOPTDLD ---
# --- Processing SOPTDLD ---
